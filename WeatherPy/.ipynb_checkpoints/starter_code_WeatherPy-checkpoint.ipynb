# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import time
import datetime
import numpy as np
import random
import requests
from config import api_key
from citipy import citipy
from api_keys import weather_api_key
from api_keys import g_key
from pprint import pprint
from scipy.stats import linregress

output_data_file = 'output_data/cities.csv'

lat = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #If unique
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print('Beginning Data Retrieval')
print('---------------------------')

url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da778ebec64581d2e8a1ac000c976aa0'

city_data = []

record = 0
sets = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    city_url = url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    record_count += 1
    try:
        city_weather = requests.get(city_url).json()
        citylat = city_weather["coord"]["lat"]
        citylng = city_weather["coord"]["lon"]
        citymaxtemp = city_weather["main"]["temp_max"]
        cityhumidity = city_weather["main"]["humidity"]
        cityclouds = city_weather["clouds"]["all"]
        citywind = city_weather["wind"]["speed"]
        citycountry = city_weather["sys"]["country"]
        citydate = city_weather["dt"]

        city_data.append({"City": city, 
                          "Lat": citylat, 
                          "Lng": citylng, 
                          "Max Temp": citymaxtemp,
                          "Humidity": cityhumidity,
                          "Cloudiness": cityclouds,
                          "Wind Speed": citywind,
                          "Country": citycountry,
                          "Date": citydate})

    # If error
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 40 of Set 49 | faridpur
# Processing Record 41 of Set 49 | qaanaaq
# Processing Record 42 of Set 49 | cape town
# Processing Record 43 of Set 49 | tuktoyaktuk
# Processing Record 44 of Set 49 | vaini
# Processing Record 45 of Set 49 | barrow
# Processing Record 46 of Set 49 | ambilobe
# Processing Record 47 of Set 49 | poya
# Processing Record 48 of Set 49 | carnarvon
# Processing Record 49 of Set 49 | khatanga
# Processing Record 50 of Set 49 | hobart
# Processing Record 51 of Set 49 | butaritari
# Processing Record 52 of Set 49 | nurota
# Processing Record 53 of Set 49 | leningradskiy
# Processing Record 54 of Set 49 | ukmerge
# Processing Record 55 of Set 49 | tasiilaq
# Processing Record 56 of Set 49 | rikitea
# Processing Record 57 of Set 49 | pevek
# Processing Record 58 of Set 49 | bredasdorp
# Processing Record 59 of Set 49 | ferrol
# Processing Record 60 of Set 49 | albany
# Processing Record 61 of Set 49 | hovd
# Processing Record 62 of Set 49 | nizhniy kuranakh
# Processing Record 63 of Set 49 | thaba-tseka
# Processing Record 64 of Set 49 | lebedyan
# Processing Record 65 of Set 49 | punta arenas
# Processing Record 66 of Set 49 | vila velha
# Processing Record 67 of Set 49 | warqla
# City not found. Skipping...
# Processing Record 68 of Set 49 | malwan
# City not found. Skipping...
# Processing Record 69 of Set 49 | asfi
# Processing Record 70 of Set 49 | port hardy
# Processing Record 71 of Set 49 | saldanha
# Processing Record 72 of Set 49 | alofi
# Processing Record 73 of Set 49 | putina
# Processing Record 74 of Set 49 | deputatskiy
# Processing Record 75 of Set 49 | oreanda
# City not found. Skipping...
# Processing Record 76 of Set 49 | mandal
# Processing Record 77 of Set 49 | hervey bay
# Processing Record 78 of Set 49 | bluff
# Processing Record 79 of Set 49 | portlethen
# Processing Record 80 of Set 49 | taolanaro
# City not found. Skipping...
# Processing Record 81 of Set 49 | clarence town
# Processing Record 82 of Set 49 | carauari
# Processing Record 83 of Set 49 | hithadhoo
# Processing Record 84 of Set 49 | kapaa
# Processing Record 85 of Set 49 | richard toll
# City not found. Skipping...
# Processing Record 86 of Set 49 | lazaro cardenas
# Processing Record 87 of Set 49 | oeiras
# Processing Record 88 of Set 49 | saint-philippe
# Processing Record 89 of Set 49 | harunabad
# Processing Record 0 of Set 50 | paita
# Processing Record 1 of Set 50 | pangnirtung
# Processing Record 2 of Set 50 | mahebourg
# Processing Record 3 of Set 50 | taitung
# Processing Record 4 of Set 50 | sungairaya
# Processing Record 5 of Set 50 | port alfred
# Processing Record 6 of Set 50 | saskylakh
# Processing Record 7 of Set 50 | tiznit
# Processing Record 8 of Set 50 | mataura
# Processing Record 9 of Set 50 | puerto ayora
# Processing Record 10 of Set 50 | riyadh
# Processing Record 11 of Set 50 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 50 | busselton
# Processing Record 13 of Set 50 | grajewo
# Processing Record 14 of Set 50 | ahipara
# Processing Record 15 of Set 50 | hermanus
# Processing Record 16 of Set 50 | ligayan
# Processing Record 17 of Set 50 | cherskiy
# Processing Record 18 of Set 50 | palagonia
# Processing Record 19 of Set 50 | ust-tsilma
# Processing Record 20 of Set 50 | luderitz
# Processing Record 21 of Set 50 | arraial do cabo
# Processing Record 22 of Set 50 | mar del plata
# Processing Record 23 of Set 50 | vanimo
# Processing Record 24 of Set 50 | avarua
# Processing Record 25 of Set 50 | harper
# Processing Record 26 of Set 50 | stoyba
# City not found. Skipping...
# Processing Record 27 of Set 50 | ribeira grande
# Processing Record 28 of Set 50 | hilo
# Processing Record 29 of Set 50 | atuona
# Processing Record 30 of Set 50 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 50 | new norfolk
# Processing Record 32 of Set 50 | ushuaia
# Processing Record 33 of Set 50 | broome
# Processing Record 34 of Set 50 | ostrovnoy
# Processing Record 35 of Set 50 | yellowknife
# Processing Record 36 of Set 50 | coahuayana
# Processing Record 37 of Set 50 | dingle
# Processing Record 38 of Set 50 | masyaf
# Processing Record 39 of Set 50 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 50 | beringovskiy
# Processing Record 41 of Set 50 | tuatapere
# Processing Record 42 of Set 50 | morant bay
# Processing Record 43 of Set 50 | faanui
# Processing Record 44 of Set 50 | chihuahua
# Processing Record 45 of Set 50 | esperance
# Processing Record 46 of Set 50 | mahibadhoo
# Processing Record 47 of Set 50 | ancud
# Processing Record 48 of Set 50 | gornyy
# Processing Record 49 of Set 50 | kenora
# Processing Record 0 of Set 51 | port elizabeth
# Processing Record 1 of Set 51 | vestmannaeyjar
# Processing Record 2 of Set 51 | fortuna
# Processing Record 3 of Set 51 | passo de camaragibe
# Processing Record 4 of Set 51 | oistins
# Processing Record 5 of Set 51 | saint george
# Processing Record 6 of Set 51 | lavrentiya
# Processing Record 7 of Set 51 | kodiak
# Processing Record 8 of Set 51 | hongjiang
# Processing Record 9 of Set 51 | bethel
# Processing Record 10 of Set 51 | gizo
# Processing Record 11 of Set 51 | liberty
# Processing Record 12 of Set 51 | sur
# Processing Record 13 of Set 51 | conceicao da barra
# Processing Record 14 of Set 51 | gao
# Processing Record 15 of Set 51 | kruisfontein
# Processing Record 16 of Set 51 | waipahu
# Processing Record 17 of Set 51 | varhaug
# Processing Record 18 of Set 51 | bambous virieux
# Processing Record 19 of Set 51 | imeni poliny osipenko
# Processing Record 20 of Set 51 | yar-sale
# Processing Record 21 of Set 51 | nowa sol
# Processing Record 22 of Set 51 | smolenka
# Processing Record 23 of Set 51 | meulaboh
# Processing Record 24 of Set 51 | pishva
# Processing Record 25 of Set 51 | cabanas
# Processing Record 26 of Set 51 | katsuura
# Processing Record 27 of Set 51 | goderich
# Processing Record 28 of Set 51 | ghatsila
# Processing Record 29 of Set 51 | provideniya
# Processing Record 30 of Set 51 | shelburne
# Processing Record 31 of Set 51 | high level
# Processing Record 32 of Set 51 | nelson bay
# Processing Record 33 of Set 51 | puerto leguizamo
# Processing Record 34 of Set 51 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 51 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 51 | yerbogachen
# Processing Record 37 of Set 51 | isiro
# Processing Record 38 of Set 51 | chokurdakh
# Processing Record 39 of Set 51 | severo-kurilsk
# Processing Record 40 of Set 51 | nishihara
# Processing Record 41 of Set 51 | mackenzie
# Processing Record 42 of Set 51 | nikolskoye
# Processing Record 43 of Set 51 | roanoke rapids
# Processing Record 44 of Set 51 | iqaluit
# Processing Record 45 of Set 51 | rock springs
# Processing Record 46 of Set 51 | saint joseph
# Processing Record 47 of Set 51 | saint-pierre
# Processing Record 48 of Set 51 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 51 | guiyang
# Processing Record 0 of Set 52 | emba
# Processing Record 1 of Set 52 | bengkulu
# Processing Record 2 of Set 52 | melilla
# Processing Record 3 of Set 52 | brigantine
# Processing Record 4 of Set 52 | nuuk
# Processing Record 5 of Set 52 | tilichiki
# Processing Record 6 of Set 52 | fairbanks
# Processing Record 7 of Set 52 | crotone
# Processing Record 8 of Set 52 | hannibal
# Processing Record 9 of Set 52 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 52 | cidreira
# Processing Record 11 of Set 52 | talnakh
# Processing Record 12 of Set 52 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 52 | kavaratti
# Processing Record 14 of Set 52 | honningsvag
# Processing Record 15 of Set 52 | constitucion
# Processing Record 16 of Set 52 | asau
# Processing Record 17 of Set 52 | nyurba
# Processing Record 18 of Set 52 | sao joao da barra
# Processing Record 19 of Set 52 | warragul
# Processing Record 20 of Set 52 | tura
# Processing Record 21 of Set 52 | chabahar
# Processing Record 22 of Set 52 | gloucester
# Processing Record 23 of Set 52 | san clemente
# Processing Record 24 of Set 52 | sola
# Processing Record 25 of Set 52 | ponta do sol
# Processing Record 26 of Set 52 | lebu
# Processing Record 27 of Set 52 | ambanja
# Processing Record 28 of Set 52 | lompoc
# Processing Record 29 of Set 52 | waddan
# Processing Record 30 of Set 52 | acapulco
# Processing Record 31 of Set 52 | georgetown
# Processing Record 32 of Set 52 | shingu
# Processing Record 33 of Set 52 | nguruka
# Processing Record 34 of Set 52 | shar
# Processing Record 35 of Set 52 | dabakala
# Processing Record 36 of Set 52 | chipinge
# Processing Record 37 of Set 52 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 52 | vao
# Processing Record 39 of Set 52 | udachnyy
# Processing Record 40 of Set 52 | lagoa
# Processing Record 41 of Set 52 | pisco
# Processing Record 42 of Set 52 | nioro
# Processing Record 43 of Set 52 | barabinsk
# Processing Record 44 of Set 52 | chara
# Processing Record 45 of Set 52 | balikpapan
# Processing Record 46 of Set 52 | stephenville
# Processing Record 47 of Set 52 | mutsamudu
# City not found. Skipping...
# Processing Record 48 of Set 52 | noumea
# Processing Record 49 of Set 52 | gat
# Processing Record 0 of Set 53 | poum
# Processing Record 1 of Set 53 | andrews
# Processing Record 2 of Set 53 | salalah
# Processing Record 3 of Set 53 | kaitangata
# Processing Record 4 of Set 53 | prieska
# Processing Record 5 of Set 53 | betong
# Processing Record 6 of Set 53 | praya
# Processing Record 7 of Set 53 | richards bay
# Processing Record 8 of Set 53 | coquimbo
# Processing Record 9 of Set 53 | espanola
# Processing Record 10 of Set 53 | nome
# Processing Record 11 of Set 53 | rawatbhata
# Processing Record 12 of Set 53 | tlahualilo
# City not found. Skipping...
# Processing Record 13 of Set 53 | cap malheureux
# Processing Record 14 of Set 53 | ilulissat
# Processing Record 15 of Set 53 | katangli
# Processing Record 16 of Set 53 | kirakira
# Processing Record 17 of Set 53 | greeneville
# Processing Record 18 of Set 53 | mount gambier
# Processing Record 19 of Set 53 | sibu
# Processing Record 20 of Set 53 | san-pedro
# Processing Record 21 of Set 53 | los llanos de aridane
# Processing Record 22 of Set 53 | turki
# Processing Record 23 of Set 53 | farah
# Processing Record 24 of Set 53 | muscat
# Processing Record 25 of Set 53 | jamestown
# Processing Record 26 of Set 53 | bata
# Processing Record 27 of Set 53 | ambulu
# Processing Record 28 of Set 53 | thompson
# Processing Record 29 of Set 53 | arlit
# Processing Record 30 of Set 53 | geraldton
# Processing Record 31 of Set 53 | castro
# Processing Record 32 of Set 53 | svarstad
# Processing Record 33 of Set 53 | biltine
# Processing Record 34 of Set 53 | horizonte
# Processing Record 35 of Set 53 | orikum
# Processing Record 36 of Set 53 | rawson
# Processing Record 37 of Set 53 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 53 | shenjiamen
# Processing Record 39 of Set 53 | susanville
# Processing Record 40 of Set 53 | hit
# Processing Record 41 of Set 53 | torbay
# Processing Record 42 of Set 53 | aklavik
# Processing Record 43 of Set 53 | clyde river
# Processing Record 44 of Set 53 | zapolyarnyy
# Processing Record 45 of Set 53 | marakkanam
# Processing Record 46 of Set 53 | superior
# Processing Record 47 of Set 53 | bilibino
# Processing Record 48 of Set 53 | yuksekova
# Processing Record 49 of Set 53 | umm lajj
# Processing Record 0 of Set 54 | chuy
# Processing Record 1 of Set 54 | henties bay
# Processing Record 2 of Set 54 | vaitape
# Processing Record 3 of Set 54 | sindor
# Processing Record 4 of Set 54 | cabo san lucas
# Processing Record 5 of Set 54 | kahului
# Processing Record 6 of Set 54 | ushumun
# Processing Record 7 of Set 54 | rio gallegos
# Processing Record 8 of Set 54 | hay river
# Processing Record 9 of Set 54 | dikson
# Processing Record 10 of Set 54 | ixtapa
# Processing Record 11 of Set 54 | kungur
# Processing Record 12 of Set 54 | xiongzhou
# Processing Record 13 of Set 54 | simao
# Processing Record 14 of Set 54 | urumqi
# Processing Record 15 of Set 54 | bereznik
# Processing Record 16 of Set 54 | korla
# Processing Record 17 of Set 54 | adrar
# Processing Record 18 of Set 54 | veraval
# Processing Record 19 of Set 54 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 54 | norman wells
# Processing Record 21 of Set 54 | mehamn
# Processing Record 22 of Set 54 | sabaudia
# Processing Record 23 of Set 54 | bambanglipuro
# Processing Record 24 of Set 54 | cascais
# Processing Record 25 of Set 54 | piacabucu
# Processing Record 26 of Set 54 | minna
# Processing Record 27 of Set 54 | honiara
# Processing Record 28 of Set 54 | batagay
# Processing Record 29 of Set 54 | naftah
# City not found. Skipping...
# Processing Record 30 of Set 54 | aswan
# Processing Record 31 of Set 54 | mumford
# Processing Record 32 of Set 54 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 54 | labuhan
# Processing Record 34 of Set 54 | mata
# Processing Record 35 of Set 54 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 54 | sembe
# Processing Record 37 of Set 54 | rabaul
# Processing Record 38 of Set 54 | karlstad
# Processing Record 39 of Set 54 | coihaique
# Processing Record 40 of Set 54 | nouadhibou
# Processing Record 41 of Set 54 | charters towers
# Processing Record 42 of Set 54 | vilyuysk
# Processing Record 43 of Set 54 | hambantota
# Processing Record 44 of Set 54 | zmeinogorsk
# Processing Record 45 of Set 54 | dzaoudzi
# Processing Record 46 of Set 54 | columbus
# Processing Record 47 of Set 54 | dauphin
# Processing Record 48 of Set 54 | pacific grove
# Processing Record 49 of Set 54 | wenatchee
# Processing Record 0 of Set 55 | krasnovishersk
# Processing Record 1 of Set 55 | hasaki
# Processing Record 2 of Set 55 | olinda
# Processing Record 3 of Set 55 | baoqing
# Processing Record 4 of Set 55 | mananjary
# Processing Record 5 of Set 55 | takanabe
# Processing Record 6 of Set 55 | kuala terengganu
# Processing Record 7 of Set 55 | jieshou
# Processing Record 8 of Set 55 | caucaia
# Processing Record 9 of Set 55 | vardo
# Processing Record 10 of Set 55 | isla mujeres
# Processing Record 11 of Set 55 | norsup
# Processing Record 12 of Set 55 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 55 | gornopravdinsk
# Processing Record 14 of Set 55 | sioux lookout
# Processing Record 15 of Set 55 | nuevitas
# Processing Record 16 of Set 55 | maniitsoq
# Processing Record 17 of Set 55 | havelock
# Processing Record 18 of Set 55 | guarapari
# Processing Record 19 of Set 55 | tommot
# Processing Record 20 of Set 55 | aripuana
# Processing Record 21 of Set 55 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 55 | maragogi
# Processing Record 23 of Set 55 | ostersund
# Processing Record 24 of Set 55 | kattivakkam
# Processing Record 25 of Set 55 | ilhabela
# Processing Record 26 of Set 55 | christchurch
# Processing Record 27 of Set 55 | sinnamary
# Processing Record 28 of Set 55 | quatre cocos
# Processing Record 29 of Set 55 | tolaga bay
# Processing Record 30 of Set 55 | acarau
# Processing Record 31 of Set 55 | oyten
# Processing Record 32 of Set 55 | san andres
# Processing Record 33 of Set 55 | nicoya
# Processing Record 34 of Set 55 | khani
# Processing Record 35 of Set 55 | puerto narino
# Processing Record 36 of Set 55 | vanavara
# Processing Record 37 of Set 55 | guaira
# Processing Record 38 of Set 55 | valdivia
# Processing Record 39 of Set 55 | lata
# Processing Record 40 of Set 55 | waipawa
# Processing Record 41 of Set 55 | perelyub
# Processing Record 42 of Set 55 | devils lake
# Processing Record 43 of Set 55 | saurimo
# Processing Record 44 of Set 55 | hobyo
# Processing Record 45 of Set 55 | solnechnyy
# Processing Record 46 of Set 55 | longyearbyen
# Processing Record 47 of Set 55 | mega
# Processing Record 48 of Set 55 | chiguayante
# Processing Record 49 of Set 55 | mazeikiai
# Processing Record 0 of Set 56 | upernavik
# Processing Record 1 of Set 56 | ucluelet
# Processing Record 2 of Set 56 | tuggurt
# City not found. Skipping...
# Processing Record 3 of Set 56 | tortoli
# Processing Record 4 of Set 56 | avera
# Processing Record 5 of Set 56 | ulladulla
# Processing Record 6 of Set 56 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 56 | wanning
# Processing Record 8 of Set 56 | fuxin
# Processing Record 9 of Set 56 | dharchula
# Processing Record 10 of Set 56 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 56 | bandarban
# Processing Record 12 of Set 56 | east london
# Processing Record 13 of Set 56 | kenai
# Processing Record 14 of Set 56 | la paz
# Processing Record 15 of Set 56 | huilong
# Processing Record 16 of Set 56 | magadan
# Processing Record 17 of Set 56 | rantepao
# Processing Record 18 of Set 56 | saint-georges
# Processing Record 19 of Set 56 | kinshasa
# Processing Record 20 of Set 56 | gawler
# Processing Record 21 of Set 56 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 56 | dunedin
# Processing Record 23 of Set 56 | singarayakonda
# Processing Record 24 of Set 56 | mudyuga
# City not found. Skipping...
# Processing Record 25 of Set 56 | abu kamal
# Processing Record 26 of Set 56 | kurumkan
# Processing Record 27 of Set 56 | srednekolymsk
# Processing Record 28 of Set 56 | nanortalik
# Processing Record 29 of Set 56 | banda aceh
# Processing Record 30 of Set 56 | san nicolas
# Processing Record 31 of Set 56 | pavlovskaya sloboda
# Processing Record 32 of Set 56 | taldan
# Processing Record 33 of Set 56 | zaysan
# Processing Record 34 of Set 56 | tambo
# Processing Record 35 of Set 56 | storsteinnes
# Processing Record 36 of Set 56 | mandalgovi
# Processing Record 37 of Set 56 | mnogovershinnyy
# Processing Record 38 of Set 56 | paamiut
# Processing Record 39 of Set 56 | guerrero negro
# Processing Record 40 of Set 56 | elko
# Processing Record 41 of Set 56 | zhezkazgan
# Processing Record 42 of Set 56 | college
# Processing Record 43 of Set 56 | ajra
# Processing Record 44 of Set 56 | aberdeen
# Processing Record 45 of Set 56 | lieksa
# Processing Record 46 of Set 56 | marovoay
# Processing Record 47 of Set 56 | utete
# Processing Record 48 of Set 56 | tateyama
# Processing Record 49 of Set 56 | port lincoln
# Processing Record 0 of Set 57 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 57 | buala
# Processing Record 2 of Set 57 | karratha
# Processing Record 3 of Set 57 | skovorodino
# Processing Record 4 of Set 57 | bubaque
# Processing Record 5 of Set 57 | comodoro rivadavia
# Processing Record 6 of Set 57 | terebovlya
# Processing Record 7 of Set 57 | manaure
# Processing Record 8 of Set 57 | calderara di reno
# Processing Record 9 of Set 57 | killam
# Processing Record 10 of Set 57 | imbituba
# Processing Record 11 of Set 57 | saint-louis
# Processing Record 12 of Set 57 | paucartambo
# City not found. Skipping...
# Processing Record 13 of Set 57 | san carlos
# Processing Record 14 of Set 57 | hami
# Processing Record 15 of Set 57 | havoysund
# Processing Record 16 of Set 57 | alta floresta
# Processing Record 17 of Set 57 | ixtacomitan
# Processing Record 18 of Set 57 | ismailia
# Processing Record 19 of Set 57 | naples
# Processing Record 20 of Set 57 | vostok
# Processing Record 21 of Set 57 | klaksvik
# Processing Record 22 of Set 57 | baijiantan
# Processing Record 23 of Set 57 | mayo
# Processing Record 24 of Set 57 | necochea
# Processing Record 25 of Set 57 | saveh
# Processing Record 26 of Set 57 | omboue
# Processing Record 27 of Set 57 | ndioum
# Processing Record 28 of Set 57 | kikwit
# Processing Record 29 of Set 57 | tiksi
# Processing Record 30 of Set 57 | metro
# Processing Record 31 of Set 57 | khor
# Processing Record 32 of Set 57 | kuito
# Processing Record 33 of Set 57 | tambopata
# Processing Record 34 of Set 57 | moose factory
# Processing Record 35 of Set 57 | khowst
# Processing Record 36 of Set 57 | half moon bay
# Processing Record 37 of Set 57 | catuday
# Processing Record 38 of Set 57 | namtsy
# Processing Record 39 of Set 57 | ampanihy
# Processing Record 40 of Set 57 | sao filipe
# Processing Record 41 of Set 57 | buzmeyin
# Processing Record 42 of Set 57 | aleksandrovka
# Processing Record 43 of Set 57 | ginda
# Processing Record 44 of Set 57 | kautokeino
# Processing Record 45 of Set 57 | kingisepp
# Processing Record 46 of Set 57 | oranjemund
# Processing Record 47 of Set 57 | villa oliva
# City not found. Skipping...
# Processing Record 48 of Set 57 | vicuna
# Processing Record 49 of Set 57 | uzumlu
# City not found. Skipping...
# Processing Record 0 of Set 58 | dudinka
# Processing Record 1 of Set 58 | dwarka
# Processing Record 2 of Set 58 | libreville
# Processing Record 3 of Set 58 | tondano
# Processing Record 4 of Set 58 | raahe
# Processing Record 5 of Set 58 | salekhard
# Processing Record 6 of Set 58 | ust-koksa
# Processing Record 7 of Set 58 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 58 | belmonte
# Processing Record 9 of Set 58 | lapua
# Processing Record 10 of Set 58 | bowen
# Processing Record 11 of Set 58 | chardara
# Processing Record 12 of Set 58 | inhambane
# Processing Record 13 of Set 58 | plettenberg bay
# Processing Record 14 of Set 58 | rio grande
# Processing Record 15 of Set 58 | kropotkin
# Processing Record 16 of Set 58 | puerto escondido
# Processing Record 17 of Set 58 | ponta delgada
# Processing Record 18 of Set 58 | mwene-ditu
# Processing Record 19 of Set 58 | shubarshi
# Processing Record 20 of Set 58 | nirmal
# Processing Record 21 of Set 58 | malanje
# Processing Record 22 of Set 58 | souillac
# Processing Record 23 of Set 58 | abadan
# Processing Record 24 of Set 58 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 58 | tsumeb
# Processing Record 26 of Set 58 | airai
# Processing Record 27 of Set 58 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 58 | laela
# Processing Record 29 of Set 58 | kangaatsiaq
# Processing Record 30 of Set 58 | sitka
# Processing Record 31 of Set 58 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 58 | one hundred mile house
# City not found. Skipping...
# Processing Record 33 of Set 58 | kishi
# Processing Record 34 of Set 58 | itai
# Processing Record 35 of Set 58 | moranbah
# Processing Record 36 of Set 58 | husavik
# Processing Record 37 of Set 58 | agboville
# Processing Record 38 of Set 58 | xuddur
# Processing Record 39 of Set 58 | akyab
# Processing Record 40 of Set 58 | antofagasta
# Processing Record 41 of Set 58 | wahiawa
# Processing Record 42 of Set 58 | storforshei
# Processing Record 43 of Set 58 | ketchikan
# Processing Record 44 of Set 58 | zhuhai
# Processing Record 45 of Set 58 | yulara
# Processing Record 46 of Set 58 | altamura
# Processing Record 47 of Set 58 | margate
# Processing Record 48 of Set 58 | padang
# Processing Record 49 of Set 58 | el balyana
# City not found. Skipping...
# Processing Record 0 of Set 59 | kontagora
# Processing Record 1 of Set 59 | ciudad bolivar
# Processing Record 2 of Set 59 | pitsunda
# Processing Record 3 of Set 59 | grand gaube
# Processing Record 4 of Set 59 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 59 | ocampo
# Processing Record 6 of Set 59 | kuah
# Processing Record 7 of Set 59 | brae
# Processing Record 8 of Set 59 | lielvarde
# Processing Record 9 of Set 59 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 59 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 59 | hudiksvall
# Processing Record 12 of Set 59 | yuzawa
# Processing Record 13 of Set 59 | arcata
# Processing Record 14 of Set 59 | osmena
# Processing Record 15 of Set 59 | olafsvik
# Processing Record 16 of Set 59 | newport
# Processing Record 17 of Set 59 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 59 | raudeberg
# Processing Record 19 of Set 59 | terra rica
# Processing Record 20 of Set 59 | vadso
# Processing Record 21 of Set 59 | amga
# Processing Record 22 of Set 59 | sisimiut
# Processing Record 23 of Set 59 | dakar
# Processing Record 24 of Set 59 | safaqis
# City not found. Skipping...
# Processing Record 25 of Set 59 | hurghada
# Processing Record 26 of Set 59 | bac can
# City not found. Skipping...
# Processing Record 27 of Set 59 | arzamas
# Processing Record 28 of Set 59 | faya
# Processing Record 29 of Set 59 | portland
# Processing Record 30 of Set 59 | quang ngai
# Processing Record 31 of Set 59 | naliya
# Processing Record 32 of Set 59 | anapskaya
# Processing Record 33 of Set 59 | zhovtneve
# Processing Record 34 of Set 59 | labytnangi
# Processing Record 35 of Set 59 | oussouye
# Processing Record 36 of Set 59 | pangody
# Processing Record 37 of Set 59 | akdepe
# Processing Record 38 of Set 59 | port blair
# Processing Record 39 of Set 59 | victoria
# Processing Record 40 of Set 59 | leh
# Processing Record 41 of Set 59 | atambua
# Processing Record 42 of Set 59 | lorengau
# Processing Record 43 of Set 59 | viedma
# Processing Record 44 of Set 59 | weiser
# Processing Record 45 of Set 59 | viransehir
# Processing Record 46 of Set 59 | north bend
# Processing Record 47 of Set 59 | parana
# Processing Record 48 of Set 59 | jinchang
# Processing Record 49 of Set 59 | camana
# Processing Record 0 of Set 60 | port augusta
# Processing Record 1 of Set 60 | kawalu
# Processing Record 2 of Set 60 | uribia
# Processing Record 3 of Set 60 | bilma
# Processing Record 4 of Set 60 | mae hong son
# Processing Record 5 of Set 60 | burica
# City not found. Skipping...
# Processing Record 6 of Set 60 | pochutla
# Processing Record 7 of Set 60 | natal
# Processing Record 8 of Set 60 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 60 | tanvald
# Processing Record 10 of Set 60 | poronaysk
# Processing Record 11 of Set 60 | atar
# Processing Record 12 of Set 60 | mitu
# Processing Record 13 of Set 60 | nemuro
# Processing Record 14 of Set 60 | grindavik
# Processing Record 15 of Set 60 | roma
# Processing Record 16 of Set 60 | general roca
# Processing Record 17 of Set 60 | batangafo
# Processing Record 18 of Set 60 | copiapo
# Processing Record 19 of Set 60 | codrington
# Processing Record 20 of Set 60 | nanchang
# Processing Record 21 of Set 60 | we
# City not found. Skipping...
# Processing Record 22 of Set 60 | sartana
# Processing Record 23 of Set 60 | harqalah
# Processing Record 24 of Set 60 | navirai
# Processing Record 25 of Set 60 | ketchenery
# City not found. Skipping...
# Processing Record 26 of Set 60 | karamay
# City not found. Skipping...
# Processing Record 27 of Set 60 | shilovo
# Processing Record 28 of Set 60 | broken hill
# Processing Record 29 of Set 60 | weyburn
# Processing Record 30 of Set 60 | dossor
# Processing Record 31 of Set 60 | turan
# Processing Record 32 of Set 60 | alice springs
# Processing Record 33 of Set 60 | westpunt
# City not found. Skipping...
# Processing Record 34 of Set 60 | walla walla
# Processing Record 35 of Set 60 | nexo
# Processing Record 36 of Set 60 | heinola
# Processing Record 37 of Set 60 | camacha
# Processing Record 38 of Set 60 | anito
# Processing Record 39 of Set 60 | galgani
# City not found. Skipping...
# Processing Record 40 of Set 60 | samarai
# Processing Record 41 of Set 60 | najran
# Processing Record 42 of Set 60 | aykino
# Processing Record 43 of Set 60 | afumati
# Processing Record 44 of Set 60 | hvide sande
# Processing Record 45 of Set 60 | halifax
# Processing Record 46 of Set 60 | pafos
# Processing Record 47 of Set 60 | monroe
# Processing Record 48 of Set 60 | thai binh
# Processing Record 49 of Set 60 | palmer
# Processing Record 0 of Set 61 | osorno
# Processing Record 1 of Set 61 | namatanai
# Processing Record 2 of Set 61 | port hedland
# Processing Record 3 of Set 61 | hamilton
# Processing Record 4 of Set 61 | marsh harbour
# Processing Record 5 of Set 61 | mufulira
# Processing Record 6 of Set 61 | pahrump
# Processing Record 7 of Set 61 | shahdadkot
# Processing Record 8 of Set 61 | ca mau
# Processing Record 9 of Set 61 | ontario
# Processing Record 10 of Set 61 | trussville
# Processing Record 11 of Set 61 | kenmare
# Processing Record 12 of Set 61 | velykoploske
# Processing Record 13 of Set 61 | belomorsk
# Processing Record 14 of Set 61 | pangai
# Processing Record 15 of Set 61 | hofn
# Processing Record 16 of Set 61 | eureka
# Processing Record 17 of Set 61 | yairipok
# Processing Record 18 of Set 61 | jujuy
# City not found. Skipping...
# Processing Record 19 of Set 61 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 61 | sampit
# Processing Record 21 of Set 61 | belaya gora
# Processing Record 22 of Set 61 | putai
# Processing Record 23 of Set 61 | banyo
# Processing Record 24 of Set 61 | gigmoto
# Processing Record 25 of Set 61 | det udom
# Processing Record 26 of Set 61 | boende
# Processing Record 27 of Set 61 | santa luzia
# Processing Record 28 of Set 61 | praia da vitoria
# Processing Record 29 of Set 61 | murgab
# Processing Record 30 of Set 61 | lakes entrance
# Processing Record 31 of Set 61 | inirida
# Processing Record 32 of Set 61 | dire dawa
# Processing Record 33 of Set 61 | yenagoa
# Processing Record 34 of Set 61 | bathsheba
# Processing Record 35 of Set 61 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 61 | darab
# Processing Record 37 of Set 61 | bumba
# Processing Record 38 of Set 61 | cobija
# Processing Record 39 of Set 61 | pasni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydatapd = pd.DataFrame(city_data)
citydatapd.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     faridpur  23.60   89.83     60.80        77          54        3.36
# 1      qaanaaq  77.48  -69.36     -2.49        81         100        0.65
# 2    cape town -33.93   18.42     64.99        62           0        4.70
# 3  tuktoyaktuk  69.45 -133.04    -23.80        74          20       10.29
# 4        vaini -21.20 -175.20     80.60        83          75       11.41
#
#   Country        Date
# 0      BD  1609548663
# 1      GL  1609548801
# 2      ZA  1609548696
# 3      CA  1609548801
# 4      TO  1609548642

# %%
pd.to_numeric(citydatapd['Lat']).astype(float)
pd.to_numeric(citydatapd['Lng']).astype(float)
pd.to_numeric(citydatapd['Max Temp']).astype(float)
pd.to_numeric(citydatapd['Humidity']).astype(float)
pd.to_numeric(citydatapd['Cloudiness']).astype(float)
pd.to_numeric(citydatapd['Wind Speed']).astype(float)
citydatapd

citydatapd.to_csv('citydatapd.csv')
citydatapd.count()
# Out:
# City          585
# Lat           585
# Lng           585
# Max Temp      585
# Humidity      585
# Cloudiness    585
# Wind Speed    585
# Country       585
# Date          585
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidcity = citydatapd[(citydatapd["Humidity"] > 100)].index                        
humidcity
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
nothumidcity = citydatapd.drop(humidcity, inplace=False)
nothumidcity.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     faridpur  23.60   89.83     60.80        77          54        3.36
# 1      qaanaaq  77.48  -69.36     -2.49        81         100        0.65
# 2    cape town -33.93   18.42     64.99        62           0        4.70
# 3  tuktoyaktuk  69.45 -133.04    -23.80        74          20       10.29
# 4        vaini -21.20 -175.20     80.60        83          75       11.41
#
#   Country        Date
# 0      BD  1609548663
# 1      GL  1609548801
# 2      ZA  1609548696
# 3      CA  1609548801
# 4      TO  1609548642

# %%
# Extract relevant fields from the data frame
lat = nothumidcity['Lat']
lng = nothumidcity['Lng']
maxtemp = nothumidcity['Max Temp']
humidity = nothumidcity['Humidity']
cloudiness = nothumidcity['Cloudiness']
windspeed = nothumidcity['Wind Speed']
country = nothumidcity['Country']

# Export the City_Data into a csv
nothumidcity.to_csv('non_humid_cities.csv', index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lat, maxtemp, edgecolor='black', facecolor='blue', linewidths=1, marker='o', alpha=0.5, label='Cities')

plt.title('City Latitude vs. Max Temperature (%s)' % time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('Lat_Temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, edgecolor='black', facecolor='blue', linewidths=1, marker='o', alpha=0.5, label='Cities')

plt.title('City Latitude vs. Humidity (%s)' % time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('Lat_Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloudiness, edgecolor='black', facecolor='blue', linewidths=1, marker='o', alpha=0.5, label='Cities')

plt.title('City Latitude vs. Cloudiness (%s)' % time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('Lat_Clouds.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, windspeed, edgecolor='black', facecolor='blue', linewidths=1, marker='o', alpha=0.5, label='Cities')

plt.title('City Latitude vs. Wind Speed (%s)' % time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('Lat_WindSpeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern = citydatapd.loc[(citydatapd['Lat'] >= 0)]
southern = citydatapd.loc[(citydatapd['Lat'] < 0)]

def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=10,color='red')
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f'The r-value is: {rvalue**2}')
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp',(0,30))
# Out:
# The r-value is: 0.6791797854140339

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp',(-55,90))
# Out:
# The r-value is: 0.13992579625649434

# %% [markdown]
# The higher r-value indicates higher correlation between latitude and temperature in the northern hemisphere, but the lower r-value indicates weaker correlation between latitude and max temperature in the Southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Humidity']
plot_linear_regression(x_values, y_values, 'Humidity',(50,30))
# Out:
# The r-value is: 0.10956737132122694

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Humidity']
plot_linear_regression(x_values, y_values, 'Humidity',(-20,30))
# Out:
# The r-value is: 0.20370181928904157

# %% [markdown]
# The lower r-value indicates weaker correlation between latitude and humidity in both hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Cloudiness']
plot_linear_regression(x_values, y_values, 'Cloudiness',(5,30))
# Out:
# The r-value is: 0.07427496335839574

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Cloudiness']
plot_linear_regression(x_values, y_values, 'Cloudiness',(-50,25))
# Out:
# The r-value is: 0.06830490649364583

# %% [markdown]
# The very low r-value indicates that there's close to zero correlation between latitude and cloudiness in both hemisphers.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Wind Speed']
plot_linear_regression(x_values, y_values, 'Wind Speed (mph)',(0,30))
# Out:
# The r-value is: 0.0013717690083075345

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Wind Speed']
plot_linear_regression(x_values, y_values, 'Wind Speed (mph)',(-15,20))
# Out:
# The r-value is: 0.12674452775252915

# %% [markdown]
# The low r-value indicates that there is a weak correlation between latitude and the wind speed. In the northern hemisphere, the correlation is extremely weak.
