# %% [markdown]
# # WeatherPy
# ----
#
# #### Observations
# * There is a higher correlation between latitude and temperature in the northern hemisphere, but it's less so in the Southern hemisphere.
# * There is a weaker correlation between latitude and humidity in both hemispheres.
# * It is safe to assume that cloudiness is not dependent on the latitude around at least this time of the year.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import time
import datetime
import numpy as np
import random
import requests
from citipy import citipy
from api_keys import weather_api_key
from api_keys import g_key
from pprint import pprint
from scipy.stats import linregress

output_data_file = 'output_data/cities.csv'

lat = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #If unique
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print('Beginning Data Retrieval')
print('---------------------------')

url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da778ebec64581d2e8a1ac000c976aa0'

city_data = []

record = 0
sets = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        sets += 1
        record = 0

    city_url = url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (record, sets, city))
    record += 1
    try:
        city_weather = requests.get(city_url).json()
        citylat = city_weather["coord"]["lat"]
        citylng = city_weather["coord"]["lon"]
        citymaxtemp = city_weather["main"]["temp_max"]
        cityhumidity = city_weather["main"]["humidity"]
        cityclouds = city_weather["clouds"]["all"]
        citywind = city_weather["wind"]["speed"]
        citycountry = city_weather["sys"]["country"]
        citydate = city_weather["dt"]

        city_data.append({"City": city, 
                          "Lat": citylat, 
                          "Lng": citylng, 
                          "Max Temp": citymaxtemp,
                          "Humidity": cityhumidity,
                          "Cloudiness": cityclouds,
                          "Wind Speed": citywind,
                          "Country": citycountry,
                          "Date": citydate})

    # If error
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 0 of Set 1 | marzuq
# Processing Record 1 of Set 1 | bandarbeyla
# Processing Record 2 of Set 1 | gillette
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | kulhudhuffushi
# Processing Record 7 of Set 1 | vardo
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 11 of Set 1 | soe
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | port-cartier
# Processing Record 14 of Set 1 | sept-iles
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | the valley
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | yar-sale
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | ostrovnoy
# Processing Record 28 of Set 1 | olden
# Processing Record 29 of Set 1 | los llanos de aridane
# Processing Record 30 of Set 1 | cairns
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | singaraja
# Processing Record 33 of Set 1 | ocos
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | opuwo
# Processing Record 36 of Set 1 | vaitape
# Processing Record 37 of Set 1 | seoul
# Processing Record 38 of Set 1 | jumla
# Processing Record 39 of Set 1 | ojinaga
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | qui nhon
# Processing Record 42 of Set 1 | anito
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | iwaki
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | airai
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 0 of Set 2 | kozhva
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | cherskiy
# Processing Record 3 of Set 2 | pokhara
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | okakarara
# Processing Record 6 of Set 2 | esmeraldas
# Processing Record 7 of Set 2 | santa maria
# Processing Record 8 of Set 2 | alibag
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | bull savanna
# Processing Record 12 of Set 2 | port lincoln
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | apricena
# Processing Record 15 of Set 2 | dallas
# Processing Record 16 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 2 | salgar
# Processing Record 18 of Set 2 | nishihara
# Processing Record 19 of Set 2 | collie
# Processing Record 20 of Set 2 | aklavik
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | mazyr
# Processing Record 23 of Set 2 | vanimo
# Processing Record 24 of Set 2 | narsaq
# Processing Record 25 of Set 2 | prieska
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | lasa
# Processing Record 28 of Set 2 | trujillo
# Processing Record 29 of Set 2 | rikitea
# Processing Record 30 of Set 2 | tautira
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | broken hill
# Processing Record 33 of Set 2 | dashitou
# Processing Record 34 of Set 2 | koboko
# Processing Record 35 of Set 2 | avera
# Processing Record 36 of Set 2 | caravelas
# Processing Record 37 of Set 2 | moree
# Processing Record 38 of Set 2 | bonnyville
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | portland
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | buala
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 2 | totskoye
# Processing Record 48 of Set 2 | vaini
# Processing Record 49 of Set 2 | constantine
# Processing Record 0 of Set 3 | srednekolymsk
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | inuvik
# Processing Record 3 of Set 3 | oxelosund
# Processing Record 4 of Set 3 | khislavichi
# Processing Record 5 of Set 3 | heihe
# Processing Record 6 of Set 3 | cotacachi
# Processing Record 7 of Set 3 | college
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | walvis bay
# Processing Record 10 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | nanakuli
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | saravan
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | poum
# Processing Record 18 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 3 | aykhal
# Processing Record 20 of Set 3 | pelagiada
# Processing Record 21 of Set 3 | fuling
# Processing Record 22 of Set 3 | syracuse
# Processing Record 23 of Set 3 | redcliffe
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | haines junction
# Processing Record 27 of Set 3 | san nicolas
# Processing Record 28 of Set 3 | huanren
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | pinega
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | areosa
# Processing Record 33 of Set 3 | khasan
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | port macquarie
# Processing Record 38 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | turukhansk
# Processing Record 41 of Set 3 | huangcun
# Processing Record 42 of Set 3 | port hedland
# Processing Record 43 of Set 3 | hami
# Processing Record 44 of Set 3 | muros
# Processing Record 45 of Set 3 | neyshabur
# Processing Record 46 of Set 3 | victoria
# Processing Record 47 of Set 3 | tsabong
# Processing Record 48 of Set 3 | salamiyah
# Processing Record 49 of Set 3 | kombissiri
# Processing Record 0 of Set 4 | misratah
# Processing Record 1 of Set 4 | kondinskoye
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | springbok
# Processing Record 4 of Set 4 | san quintin
# Processing Record 5 of Set 4 | saint-leu
# Processing Record 6 of Set 4 | qixingtai
# Processing Record 7 of Set 4 | atherton
# Processing Record 8 of Set 4 | waipawa
# Processing Record 9 of Set 4 | schwedt
# Processing Record 10 of Set 4 | pyaozerskiy
# Processing Record 11 of Set 4 | paamiut
# Processing Record 12 of Set 4 | henties bay
# Processing Record 13 of Set 4 | port elizabeth
# Processing Record 14 of Set 4 | dikson
# Processing Record 15 of Set 4 | ayna
# Processing Record 16 of Set 4 | hithadhoo
# Processing Record 17 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 4 | bac lieu
# Processing Record 21 of Set 4 | mao
# Processing Record 22 of Set 4 | mnogovershinnyy
# Processing Record 23 of Set 4 | fort wellington
# Processing Record 24 of Set 4 | bairiki
# Processing Record 25 of Set 4 | constitucion
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | sao felix do xingu
# Processing Record 28 of Set 4 | ust-tsilma
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | mbini
# Processing Record 31 of Set 4 | nanortalik
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 4 | karatau
# Processing Record 35 of Set 4 | tatarskaya pishlya
# Processing Record 36 of Set 4 | port hardy
# Processing Record 37 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 4 | mount darwin
# Processing Record 39 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 4 | chapais
# Processing Record 41 of Set 4 | punta alta
# Processing Record 42 of Set 4 | dingle
# Processing Record 43 of Set 4 | havoysund
# Processing Record 44 of Set 4 | new norfolk
# Processing Record 45 of Set 4 | tsogni
# Processing Record 46 of Set 4 | pajan
# Processing Record 47 of Set 4 | pevek
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | little current
# Processing Record 0 of Set 5 | hendijan
# City not found. Skipping...
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | barranca
# Processing Record 3 of Set 5 | santa helena de goias
# Processing Record 4 of Set 5 | dunedin
# Processing Record 5 of Set 5 | khandyga
# Processing Record 6 of Set 5 | nata
# Processing Record 7 of Set 5 | george town
# Processing Record 8 of Set 5 | verkhnyaya inta
# Processing Record 9 of Set 5 | mount gambier
# Processing Record 10 of Set 5 | mackay
# Processing Record 11 of Set 5 | nalut
# Processing Record 12 of Set 5 | eenhana
# Processing Record 13 of Set 5 | ejura
# Processing Record 14 of Set 5 | chokurdakh
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | naze
# Processing Record 17 of Set 5 | baykit
# Processing Record 18 of Set 5 | kitimat
# Processing Record 19 of Set 5 | cayenne
# Processing Record 20 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | touros
# Processing Record 23 of Set 5 | margate
# Processing Record 24 of Set 5 | vila
# Processing Record 25 of Set 5 | anchorage
# Processing Record 26 of Set 5 | hoa binh
# Processing Record 27 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 5 | mikhaylovka
# Processing Record 29 of Set 5 | nikolskoye
# Processing Record 30 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 5 | didsbury
# Processing Record 32 of Set 5 | maniitsoq
# Processing Record 33 of Set 5 | puerto carreno
# Processing Record 34 of Set 5 | jinxi
# Processing Record 35 of Set 5 | codrington
# Processing Record 36 of Set 5 | lagoa
# Processing Record 37 of Set 5 | zabol
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | jalu
# Processing Record 40 of Set 5 | mayo
# Processing Record 41 of Set 5 | adrar
# Processing Record 42 of Set 5 | marsa matruh
# Processing Record 43 of Set 5 | praia da vitoria
# Processing Record 44 of Set 5 | ilulissat
# Processing Record 45 of Set 5 | vostok
# Processing Record 46 of Set 5 | burns lake
# Processing Record 47 of Set 5 | ilinskiy
# Processing Record 48 of Set 5 | eregli
# Processing Record 49 of Set 5 | komsomolskiy
# Processing Record 0 of Set 6 | tilichiki
# Processing Record 1 of Set 6 | weatherford
# Processing Record 2 of Set 6 | semporna
# Processing Record 3 of Set 6 | nemuro
# Processing Record 4 of Set 6 | necochea
# Processing Record 5 of Set 6 | hambantota
# Processing Record 6 of Set 6 | natal
# Processing Record 7 of Set 6 | saveh
# Processing Record 8 of Set 6 | isangel
# Processing Record 9 of Set 6 | bathsheba
# Processing Record 10 of Set 6 | kiama
# Processing Record 11 of Set 6 | topeka
# Processing Record 12 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | arinos
# Processing Record 14 of Set 6 | libertador general san martin
# Processing Record 15 of Set 6 | coahuayana
# Processing Record 16 of Set 6 | lensk
# Processing Record 17 of Set 6 | iberia
# Processing Record 18 of Set 6 | villa maria
# Processing Record 19 of Set 6 | west fargo
# Processing Record 20 of Set 6 | gawler
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | hofn
# Processing Record 23 of Set 6 | glace bay
# Processing Record 24 of Set 6 | katsuura
# Processing Record 25 of Set 6 | beringovskiy
# Processing Record 26 of Set 6 | qaanaaq
# Processing Record 27 of Set 6 | tingo maria
# Processing Record 28 of Set 6 | moerai
# Processing Record 29 of Set 6 | krasnoselkup
# Processing Record 30 of Set 6 | puerto del rosario
# Processing Record 31 of Set 6 | kaitangata
# Processing Record 32 of Set 6 | eureka
# Processing Record 33 of Set 6 | ulkan
# Processing Record 34 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 6 | san fernando
# Processing Record 36 of Set 6 | new waterford
# Processing Record 37 of Set 6 | inverness
# Processing Record 38 of Set 6 | souillac
# Processing Record 39 of Set 6 | koungou
# Processing Record 40 of Set 6 | sevojno
# Processing Record 41 of Set 6 | kavaratti
# Processing Record 42 of Set 6 | gaomi
# Processing Record 43 of Set 6 | grindavik
# Processing Record 44 of Set 6 | severo-kurilsk
# Processing Record 45 of Set 6 | tasiilaq
# Processing Record 46 of Set 6 | kamaishi
# Processing Record 47 of Set 6 | olinda
# Processing Record 48 of Set 6 | abu kamal
# Processing Record 49 of Set 6 | marathon
# Processing Record 0 of Set 7 | miandrivazo
# Processing Record 1 of Set 7 | katangli
# Processing Record 2 of Set 7 | izumo
# Processing Record 3 of Set 7 | sorong
# Processing Record 4 of Set 7 | vila velha
# Processing Record 5 of Set 7 | xiaoweizhai
# Processing Record 6 of Set 7 | grants
# Processing Record 7 of Set 7 | kieta
# Processing Record 8 of Set 7 | aquiraz
# Processing Record 9 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 7 | camana
# Processing Record 11 of Set 7 | torbay
# Processing Record 12 of Set 7 | sedhiou
# Processing Record 13 of Set 7 | indramayu
# Processing Record 14 of Set 7 | peniche
# Processing Record 15 of Set 7 | mahajanga
# Processing Record 16 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 7 | amli
# Processing Record 18 of Set 7 | dwarka
# Processing Record 19 of Set 7 | kamenka
# Processing Record 20 of Set 7 | koudougou
# Processing Record 21 of Set 7 | olbia
# Processing Record 22 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 23 of Set 7 | shelburne
# Processing Record 24 of Set 7 | fairbanks
# Processing Record 25 of Set 7 | birobidzhan
# Processing Record 26 of Set 7 | siteki
# Processing Record 27 of Set 7 | sistranda
# Processing Record 28 of Set 7 | husavik
# Processing Record 29 of Set 7 | norman wells
# Processing Record 30 of Set 7 | den helder
# Processing Record 31 of Set 7 | saint-augustin
# Processing Record 32 of Set 7 | thinadhoo
# Processing Record 33 of Set 7 | novikovo
# Processing Record 34 of Set 7 | kempsey
# Processing Record 35 of Set 7 | karasjok
# Processing Record 36 of Set 7 | pisco
# Processing Record 37 of Set 7 | zeya
# Processing Record 38 of Set 7 | san rafael
# Processing Record 39 of Set 7 | qaqortoq
# Processing Record 40 of Set 7 | sinjai
# Processing Record 41 of Set 7 | wote
# Processing Record 42 of Set 7 | attur
# Processing Record 43 of Set 7 | palu
# Processing Record 44 of Set 7 | sabha
# Processing Record 45 of Set 7 | tutoia
# Processing Record 46 of Set 7 | pizarro
# Processing Record 47 of Set 7 | saint-denis
# Processing Record 48 of Set 7 | lira
# Processing Record 49 of Set 7 | cananeia
# Processing Record 0 of Set 8 | panji
# Processing Record 1 of Set 8 | lianran
# Processing Record 2 of Set 8 | northam
# Processing Record 3 of Set 8 | richards bay
# Processing Record 4 of Set 8 | tutubigan
# Processing Record 5 of Set 8 | geraldton
# Processing Record 6 of Set 8 | kruisfontein
# Processing Record 7 of Set 8 | ketchikan
# Processing Record 8 of Set 8 | roma
# Processing Record 9 of Set 8 | parfenyevo
# Processing Record 10 of Set 8 | arraial do cabo
# Processing Record 11 of Set 8 | gangapur
# Processing Record 12 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 13 of Set 8 | vestmannaeyjar
# Processing Record 14 of Set 8 | marsh harbour
# Processing Record 15 of Set 8 | tuktoyaktuk
# Processing Record 16 of Set 8 | sao joao da barra
# Processing Record 17 of Set 8 | lithakia
# Processing Record 18 of Set 8 | piacabucu
# Processing Record 19 of Set 8 | tuatapere
# Processing Record 20 of Set 8 | smolyaninovo
# Processing Record 21 of Set 8 | chernyshevskiy
# Processing Record 22 of Set 8 | abu zabad
# Processing Record 23 of Set 8 | christchurch
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | lavrentiya
# Processing Record 26 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 27 of Set 8 | saint anthony
# Processing Record 28 of Set 8 | cidreira
# Processing Record 29 of Set 8 | sabang
# Processing Record 30 of Set 8 | guerrero negro
# Processing Record 31 of Set 8 | uyuni
# Processing Record 32 of Set 8 | tamale
# Processing Record 33 of Set 8 | robore
# Processing Record 34 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 8 | catamarca
# Processing Record 36 of Set 8 | yangjiang
# Processing Record 37 of Set 8 | alekseyevsk
# Processing Record 38 of Set 8 | loviisa
# Processing Record 39 of Set 8 | bilokurakyne
# Processing Record 40 of Set 8 | lodja
# Processing Record 41 of Set 8 | talnakh
# Processing Record 42 of Set 8 | sao joao do paraiso
# Processing Record 43 of Set 8 | santa cruz de tenerife
# Processing Record 44 of Set 8 | zhangjiakou
# Processing Record 45 of Set 8 | mizan teferi
# Processing Record 46 of Set 8 | tatui
# Processing Record 47 of Set 8 | linxi
# Processing Record 48 of Set 8 | gamba
# Processing Record 49 of Set 8 | saldanha
# Processing Record 0 of Set 9 | pandan
# Processing Record 1 of Set 9 | biak
# Processing Record 2 of Set 9 | stodolishche
# Processing Record 3 of Set 9 | gravdal
# Processing Record 4 of Set 9 | nanga eboko
# Processing Record 5 of Set 9 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 6 of Set 9 | strezhevoy
# Processing Record 7 of Set 9 | road town
# Processing Record 8 of Set 9 | ternate
# Processing Record 9 of Set 9 | charters towers
# Processing Record 10 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 11 of Set 9 | agadez
# Processing Record 12 of Set 9 | mocuba
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | lata
# Processing Record 15 of Set 9 | havre-saint-pierre
# Processing Record 16 of Set 9 | worland
# Processing Record 17 of Set 9 | gat
# Processing Record 18 of Set 9 | ponta delgada
# Processing Record 19 of Set 9 | king of prussia
# Processing Record 20 of Set 9 | chiredzi
# Processing Record 21 of Set 9 | salinopolis
# Processing Record 22 of Set 9 | makakilo city
# Processing Record 23 of Set 9 | sao filipe
# Processing Record 24 of Set 9 | robertsport
# Processing Record 25 of Set 9 | nome
# Processing Record 26 of Set 9 | ulladulla
# Processing Record 27 of Set 9 | ust-nera
# Processing Record 28 of Set 9 | fernley
# Processing Record 29 of Set 9 | meadow lake
# Processing Record 30 of Set 9 | anadyr
# Processing Record 31 of Set 9 | faya
# Processing Record 32 of Set 9 | pinawa
# Processing Record 33 of Set 9 | ayios matthaios
# City not found. Skipping...
# Processing Record 34 of Set 9 | tokonou
# Processing Record 35 of Set 9 | kholtoson
# Processing Record 36 of Set 9 | lanzhou
# Processing Record 37 of Set 9 | amapa
# Processing Record 38 of Set 9 | saint-pierre
# Processing Record 39 of Set 9 | bay city
# Processing Record 40 of Set 9 | sharjah
# Processing Record 41 of Set 9 | chuzhou
# Processing Record 42 of Set 9 | sumbawanga
# Processing Record 43 of Set 9 | gizo
# Processing Record 44 of Set 9 | visegrad
# Processing Record 45 of Set 9 | joao camara
# Processing Record 46 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 9 | tuy hoa
# Processing Record 48 of Set 9 | xining
# Processing Record 49 of Set 9 | pemba
# Processing Record 0 of Set 10 | bilma
# Processing Record 1 of Set 10 | ostersund
# Processing Record 2 of Set 10 | birjand
# Processing Record 3 of Set 10 | lima
# Processing Record 4 of Set 10 | takhatgarh
# Processing Record 5 of Set 10 | sulmona
# Processing Record 6 of Set 10 | araguaina
# Processing Record 7 of Set 10 | half moon bay
# Processing Record 8 of Set 10 | ayan
# Processing Record 9 of Set 10 | takaka
# Processing Record 10 of Set 10 | maromitsa
# Processing Record 11 of Set 10 | lujan
# Processing Record 12 of Set 10 | ibotirama
# Processing Record 13 of Set 10 | neiafu
# Processing Record 14 of Set 10 | mbandaka
# Processing Record 15 of Set 10 | chokwe
# Processing Record 16 of Set 10 | kashi
# Processing Record 17 of Set 10 | bayan
# Processing Record 18 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 10 | alice springs
# Processing Record 20 of Set 10 | moose jaw
# Processing Record 21 of Set 10 | cockburn town
# Processing Record 22 of Set 10 | aksarayskiy
# Processing Record 23 of Set 10 | sangar
# Processing Record 24 of Set 10 | olafsvik
# Processing Record 25 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 10 | samarai
# Processing Record 27 of Set 10 | burica
# City not found. Skipping...
# Processing Record 28 of Set 10 | jardim
# Processing Record 29 of Set 10 | antofagasta
# Processing Record 30 of Set 10 | troitsko-pechorsk
# Processing Record 31 of Set 10 | likhoslavl
# Processing Record 32 of Set 10 | kloulklubed
# Processing Record 33 of Set 10 | kahului
# Processing Record 34 of Set 10 | ust-kuyga
# Processing Record 35 of Set 10 | raipur
# Processing Record 36 of Set 10 | santa cruz del norte
# Processing Record 37 of Set 10 | valley
# Processing Record 38 of Set 10 | sayhat
# Processing Record 39 of Set 10 | meulaboh
# Processing Record 40 of Set 10 | paita
# Processing Record 41 of Set 10 | macara
# Processing Record 42 of Set 10 | abaza
# Processing Record 43 of Set 10 | batangafo
# Processing Record 44 of Set 10 | bengkulu
# Processing Record 45 of Set 10 | keetmanshoop
# Processing Record 46 of Set 10 | clyde river
# Processing Record 47 of Set 10 | damghan
# Processing Record 48 of Set 10 | uk
# City not found. Skipping...
# Processing Record 49 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 0 of Set 11 | berlevag
# Processing Record 1 of Set 11 | sosnovo-ozerskoye
# Processing Record 2 of Set 11 | flinders
# Processing Record 3 of Set 11 | sur
# Processing Record 4 of Set 11 | tondano
# Processing Record 5 of Set 11 | ye
# City not found. Skipping...
# Processing Record 6 of Set 11 | quelimane
# Processing Record 7 of Set 11 | taksimo
# Processing Record 8 of Set 11 | menzelinsk
# Processing Record 9 of Set 11 | la ronge
# Processing Record 10 of Set 11 | bollnas
# Processing Record 11 of Set 11 | bluffton
# Processing Record 12 of Set 11 | ambalavao
# Processing Record 13 of Set 11 | comodoro rivadavia
# Processing Record 14 of Set 11 | sortland
# Processing Record 15 of Set 11 | lashio
# Processing Record 16 of Set 11 | tyukalinsk
# Processing Record 17 of Set 11 | popondetta
# Processing Record 18 of Set 11 | rahuri
# Processing Record 19 of Set 11 | floro
# Processing Record 20 of Set 11 | north bend
# Processing Record 21 of Set 11 | prince george
# Processing Record 22 of Set 11 | impfondo
# Processing Record 23 of Set 11 | satipo
# Processing Record 24 of Set 11 | conceicao do castelo
# Processing Record 25 of Set 11 | padang
# Processing Record 26 of Set 11 | pumiao
# Processing Record 27 of Set 11 | lindsay
# Processing Record 28 of Set 11 | warwick
# Processing Record 29 of Set 11 | teeli
# Processing Record 30 of Set 11 | port augusta
# Processing Record 31 of Set 11 | wanning
# Processing Record 32 of Set 11 | simbach
# Processing Record 33 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 34 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 11 | ondangwa
# Processing Record 36 of Set 11 | mana
# Processing Record 37 of Set 11 | harbour breton
# Processing Record 38 of Set 11 | vilhena
# Processing Record 39 of Set 11 | pacifica
# Processing Record 40 of Set 11 | yulara
# Processing Record 41 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 42 of Set 11 | rocha
# Processing Record 43 of Set 11 | grand gaube
# Processing Record 44 of Set 11 | weligama
# Processing Record 45 of Set 11 | tura
# Processing Record 46 of Set 11 | ankpa
# Processing Record 47 of Set 11 | eganville
# Processing Record 48 of Set 11 | omboue
# Processing Record 49 of Set 11 | honiara
# Processing Record 0 of Set 12 | asau
# Processing Record 1 of Set 12 | kotma
# Processing Record 2 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 12 | xuddur
# Processing Record 4 of Set 12 | suzu
# City not found. Skipping...
# Processing Record 5 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 12 | batagay-alyta
# Processing Record 8 of Set 12 | lazarev
# Processing Record 9 of Set 12 | roros
# Processing Record 10 of Set 12 | kaya
# Processing Record 11 of Set 12 | guarenas
# Processing Record 12 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | nelson bay
# Processing Record 14 of Set 12 | rawson
# Processing Record 15 of Set 12 | mogocha
# Processing Record 16 of Set 12 | marawi
# Processing Record 17 of Set 12 | tecoanapa
# Processing Record 18 of Set 12 | knysna
# Processing Record 19 of Set 12 | yumen
# Processing Record 20 of Set 12 | kenora
# Processing Record 21 of Set 12 | sindand
# City not found. Skipping...
# Processing Record 22 of Set 12 | oriximina
# Processing Record 23 of Set 12 | pauini
# Processing Record 24 of Set 12 | svetlaya
# Processing Record 25 of Set 12 | harper
# Processing Record 26 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 12 | ouro preto do oeste
# Processing Record 28 of Set 12 | porbandar
# Processing Record 29 of Set 12 | boksitogorsk
# Processing Record 30 of Set 12 | dicabisagan
# Processing Record 31 of Set 12 | carikar
# City not found. Skipping...
# Processing Record 32 of Set 12 | igualada
# Processing Record 33 of Set 12 | sovetskiy
# Processing Record 34 of Set 12 | ahipara
# Processing Record 35 of Set 12 | dapaong
# Processing Record 36 of Set 12 | sydney
# Processing Record 37 of Set 12 | manokwari
# Processing Record 38 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 12 | udachnyy
# Processing Record 40 of Set 12 | bowen
# Processing Record 41 of Set 12 | tocopilla
# Processing Record 42 of Set 12 | kango
# Processing Record 43 of Set 12 | palmer
# Processing Record 44 of Set 12 | marmaris
# Processing Record 45 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 12 | riyadh
# Processing Record 47 of Set 12 | tottori
# Processing Record 48 of Set 12 | bonavista
# Processing Record 49 of Set 12 | thohoyandou
# Processing Record 0 of Set 13 | port-gentil
# Processing Record 1 of Set 13 | horsham
# Processing Record 2 of Set 13 | elat
# Processing Record 3 of Set 13 | tukrah
# Processing Record 4 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 5 of Set 13 | san jeronimo
# Processing Record 6 of Set 13 | port blair
# Processing Record 7 of Set 13 | ngunguru
# Processing Record 8 of Set 13 | venado tuerto
# Processing Record 9 of Set 13 | yinchuan
# Processing Record 10 of Set 13 | jackson
# Processing Record 11 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 13 | yerbogachen
# Processing Record 13 of Set 13 | phalodi
# Processing Record 14 of Set 13 | dolores
# Processing Record 15 of Set 13 | santa rosa
# Processing Record 16 of Set 13 | ulaangom
# Processing Record 17 of Set 13 | canyon
# Processing Record 18 of Set 13 | varhaug
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydatapd = pd.DataFrame(city_data)
citydatapd.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        marzuq  14.40   46.47     69.13        35          62        6.64
# 1   bandarbeyla   9.49   50.81     76.24        64          48       19.55
# 2      gillette  44.29 -105.50     28.40        54           1       18.34
# 3  punta arenas -53.15  -70.92     53.60        58           0       26.40
# 4   port alfred -33.59   26.89     68.00        70          45        1.99
#
#   Country        Date
# 0      YE  1609565601
# 1      SO  1609565601
# 2      US  1609565602
# 3      CL  1609565362
# 4      ZA  1609565602

# %%
pd.to_numeric(citydatapd['Lat']).astype(float)
pd.to_numeric(citydatapd['Lng']).astype(float)
pd.to_numeric(citydatapd['Max Temp']).astype(float)
pd.to_numeric(citydatapd['Humidity']).astype(float)
pd.to_numeric(citydatapd['Cloudiness']).astype(float)
pd.to_numeric(citydatapd['Wind Speed']).astype(float)
citydatapd

citydatapd.to_csv('citydatapd.csv')
citydatapd.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidcity = citydatapd[(citydatapd["Humidity"] > 100)].index                        
humidcity
# Out:
# Int64Index([], dtype='int64')

# %%
nothumidcity = citydatapd.drop(humidcity, inplace=False)
nothumidcity.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        marzuq  14.40   46.47     69.13        35          62        6.64
# 1   bandarbeyla   9.49   50.81     76.24        64          48       19.55
# 2      gillette  44.29 -105.50     28.40        54           1       18.34
# 3  punta arenas -53.15  -70.92     53.60        58           0       26.40
# 4   port alfred -33.59   26.89     68.00        70          45        1.99
#
#   Country        Date
# 0      YE  1609565601
# 1      SO  1609565601
# 2      US  1609565602
# 3      CL  1609565362
# 4      ZA  1609565602

# %%
# Extract relevant fields from the data frame
lat = nothumidcity['Lat']
lng = nothumidcity['Lng']
maxtemp = nothumidcity['Max Temp']
humidity = nothumidcity['Humidity']
cloudiness = nothumidcity['Cloudiness']
windspeed = nothumidcity['Wind Speed']
country = nothumidcity['Country']

# Export the City_Data into a csv
nothumidcity.to_csv('non_humid_cities.csv', index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lat, maxtemp, edgecolor='black', facecolor='blue', linewidths=1, marker='o', alpha=0.5, label='Cities')

plt.title('City Latitude vs. Max Temperature (%s)' % time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('../output_data/Lat_Temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, edgecolor='black', facecolor='blue', linewidths=1, marker='o', alpha=0.5, label='Cities')

plt.title('City Latitude vs. Humidity (%s)' % time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('../output_data/Lat_Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloudiness, edgecolor='black', facecolor='blue', linewidths=1, marker='o', alpha=0.5, label='Cities')

plt.title('City Latitude vs. Cloudiness (%s)' % time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('../output_data/Lat_Clouds.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, windspeed, edgecolor='black', facecolor='blue', linewidths=1, marker='o', alpha=0.5, label='Cities')

plt.title('City Latitude vs. Wind Speed (%s)' % time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('../output_data/Lat_WindSpeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern = citydatapd.loc[(citydatapd['Lat'] >= 0)]
southern = citydatapd.loc[(citydatapd['Lat'] < 0)]

def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=10,color='red')
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f'The r-value is: {rvalue**2}')
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp',(0,30))
# Out:
# The r-value is: 0.7087432899736009

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Max Temp']
plot_linear_regression(x_values, y_values, 'Max Temp',(-55,90))
# Out:
# The r-value is: 0.22330386774975014

# %% [markdown]
# The higher r-value indicates higher correlation between latitude and temperature in the northern hemisphere, but the lower r-value indicates weaker correlation between latitude and max temperature in the Southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Humidity']
plot_linear_regression(x_values, y_values, 'Humidity',(50,30))
# Out:
# The r-value is: 0.1255376306489879

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Humidity']
plot_linear_regression(x_values, y_values, 'Humidity',(-20,30))
# Out:
# The r-value is: 0.06812616227841702

# %% [markdown]
# The lower r-value indicates weaker correlation between latitude and humidity in both hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Cloudiness']
plot_linear_regression(x_values, y_values, 'Cloudiness',(5,30))
# Out:
# The r-value is: 0.043477200216332404

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Cloudiness']
plot_linear_regression(x_values, y_values, 'Cloudiness',(-50,25))
# Out:
# The r-value is: 0.0661054697090943

# %% [markdown]
# The very low r-value indicates that there's close to zero correlation between latitude and cloudiness in both hemisphers.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Wind Speed']
plot_linear_regression(x_values, y_values, 'Wind Speed (mph)',(0,30))
# Out:
# The r-value is: 0.00499132981599812

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Wind Speed']
plot_linear_regression(x_values, y_values, 'Wind Speed (mph)',(-15,20))
# Out:
# The r-value is: 0.12084555164540302

# %% [markdown]
# The low r-value indicates that there is a weak correlation between latitude and the wind speed. In the northern hemisphere, the correlation is extremely weak.
